# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MohamedAfifii/Route-AI-for-Self-Driving-Cars-Course-Material/blob/main/Week-1/matplotlib.ipynb)

# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-9rlfede_ because the default path (/home/afifi/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# ## Plotting

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)
plt.show()       # You can remove it in notebooks!

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)                 # Doesn't remove old plots on the figure
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# %% [markdown]
# ## Subplots

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)        # This doesn't erase the old subplot
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# # An easier way to create subplots

# %%
# 2 rows, 1 column
fig, axes = plt.subplots(2, 1)

axes[0].plot(x, y_sin)
axes[0].set_title('Sine')

axes[1].plot(x, y_cos)
axes[1].set_title('Cosine')
# Out:
# Text(0.5, 1.0, 'Cosine')

# %%
# 2 rows, 2 columns
fig, axes = plt.subplots(2, 2)  
fig.set_figwidth(10)
fig.set_figheight(8)

# Upper left 
axes[0, 0].plot(x, y_sin)
axes[0, 0].set_title('Sine')

# Upper right
axes[0, 1].plot(x, x)
axes[0, 1].set_title('Linear')

# Buttom left
axes[1, 0].plot(x, y_cos)
axes[1, 0].set_title('Cosine')

# Buttom right will be empty because we didn't plot anything to axes[1, 1]
# Out:
# Text(0.5, 1.0, 'Cosine')
